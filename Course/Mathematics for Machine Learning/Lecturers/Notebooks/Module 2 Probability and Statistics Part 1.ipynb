# %%
# @title Welcome

from IPython.display import HTML

HTML('''
<div style="padding: 20px; background: linear-gradient(90deg, #a64ac9, #ff66b2); color: white; text-align: center; border-radius: 10px; font-size: 28px; font-weight: bold;">
  iAAA: Mathematics for Machine Learning
</div>
''')
# Out:
# <div style="padding: 20px; background: linear-gradient(90deg, #a64ac9, #ff66b2); color: white; text-align: center; border-radius: 10px; font-size: 28px; font-weight: bold;">
#   iAAA: Mathematics for Machine Learning
# </div>

# %% [markdown]
# ### 📝 Notebook Topic: *Probabilistics & Statistics*
# 👨‍🏫 Lecturer: *Hadi Asheri*
# 📅 Date: *[YYYY-MM-DD]*

# %% [markdown]
# ---

# %% [markdown]
# <h1 style='text-align: right;'>
# آزمایش پرتاب سکه
# </h1>

# %%
# @title Section 1: Coin Flip Test
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 1: Coin Flip Test
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 1: Coin Flip Test
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulation parameters
num_trials = 1000  # Number of coin tosses
coin_sides = ["Heads", "Tails"]

# Simulate coin tosses
tosses = np.random.choice(coin_sides, num_trials)

# Count occurrences of each outcome
heads_count = np.sum(tosses == "Heads")
tails_count = np.sum(tosses == "Tails")

# Compute empirical probabilities
empirical_probabilities = [heads_count / num_trials, tails_count / num_trials]
print(empirical_probabilities)

# Create bar chart
fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(coin_sides, empirical_probabilities, color=["blue", "green"], alpha=0.7)

# Labeling the plot
ax.set_ylabel("Empirical Probability")
ax.set_title(f"Probability Space for {num_trials} Coin Tosses")
ax.set_ylim(0, 1)
ax.grid(axis="y", linestyle="--", alpha=0.5)

# Show the plot
plt.show()
# Out:
# [np.float64(0.517), np.float64(0.483)]

# %% [markdown]
# <h1 style='text-align: right;'>
# آزمایش پرتاب تاس
# </h1>

# %%
# @title Section 2: Dice Roll Test
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 2: Dice Roll Test
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 2: Dice Roll Test
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulation parameters
num_rolls = 10000  # Number of die rolls
die_faces = np.arange(1, 7)  # Possible outcomes: 1 to 6

# Simulate die rolls
rolls = np.random.choice(die_faces, num_rolls)

# Count occurrences of each face
counts = np.bincount(rolls, minlength=7)[1:]  # Ignore index 0

# Compute empirical probabilities
empirical_probabilities = counts / num_rolls

# Create bar chart
fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(die_faces, empirical_probabilities, color="blue", alpha=0.7)

# Labeling the plot
ax.set_xlabel("Die Face")
ax.set_ylabel("Empirical Probability")
ax.set_title(f"Probability Space for {num_rolls} Rolls")
ax.set_ylim(0, 1)
ax.grid(axis="y", linestyle="--", alpha=0.5)

# Show the plot
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# PCA
# کاهش بعد
# </h1>

# %%
# @title Section 3: PCA
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 3: Principle Components Analysis
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 3: Principle Components Analysis
# </div>

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Define the probabilities for events A and B
p_A = 0.5  # Probability of A
p_B = 0.5  # Probability of B
p_AB = 0.1  # Probability of A ∩ B (mutually exclusive events)

# Plot the Venn diagram
venn = venn2(subsets=(p_A, p_B, p_AB), set_labels=('A', 'B'))

# Set the title and labels
plt.title("Visualization of Kolmogorov Axioms using Venn Diagram")

# Add annotation for the axioms
plt.text(-0.7, 0.2, "P(A) = 0.4", fontsize=12, color="blue")
plt.text(0.7, 0.2, "P(B) = 0.3", fontsize=12, color="green")
plt.text(0.0, -0.3, "P(A ∩ B) = 0", fontsize=12, color="black")

# Show the plot
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# آزمایش پرتاب دو سکه
# </h1>

# %%
# @title Section 4: Two coins flip
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 4: Two coins flip
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 4: Two coins flip
# </div>

# %%
import random
import matplotlib.pyplot as plt

def toss_two_coins():
    # Toss two coins: each can be 'Heads' or 'Tails'
    coin1 = random.choice(['H', 'T'])
    coin2 = random.choice(['H', 'T'])
    return coin1, coin2

# Simulate the tossing of two coins 1000 times
n_tosses = 100
outcomes = {'HH': 0, 'HT': 0, 'TH': 0, 'TT': 0}

# Simulating the experiment
for _ in range(n_tosses):
    result = toss_two_coins()
    outcome = ''.join(result)  # Combine the result into a string (e.g., "HT")
    outcomes[outcome] += 1

# Plotting: Bar Chart for the frequencies of outcomes
labels = list(outcomes.keys())
values = list(outcomes.values())
values = [v/n_tosses for v in values]

# Bar chart to show frequency of each outcome
plt.figure(figsize=(8, 5))
plt.bar(labels, values, color=['red', 'green', 'blue', 'orange'])
plt.title(f"Outcome Frequencies for Tossing Two Coins ({n_tosses} Simulations)")
plt.xlabel("Outcomes")
plt.ylabel("Frequency")
plt.show()

# Optional: Pie chart for visualizing the proportions of outcomes
plt.figure(figsize=(7, 7))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green', 'blue', 'orange'])
plt.title(f"Outcome Proportions for Tossing Two Coins ({n_tosses} Simulations)")
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# توزیع نرمال
# </h1>

# %%
# @title Section 5: Normal Distribution
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 5: Normal Distribution
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 5: Normal Distribution
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 1D Normal Distribution Visualization
def plot_1d_normal(mu=0, sigma=1, num_points=1000):
    # Generate values for the x-axis
    x = np.linspace(mu - 4*sigma, mu + 4*sigma, num_points)

    # Get the corresponding y values of the PDF of the normal distribution
    y = norm.pdf(x, mu, sigma)

    # Plot the 1D normal distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label=f'Normal Distribution\n$\mu={mu}$, $\sigma={sigma}$', color='blue')
    plt.fill_between(x, y, color='blue', alpha=0.2)
    plt.title("1D Normal Distribution")
    plt.xlabel("X")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.legend()
    plt.show()


# Visualize 1D Normal Distribution with mean 0 and std dev 1
plot_1d_normal(mu=0, sigma=1)
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1207476062.py:15: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(x, y, label=f'Normal Distribution\n$\mu={mu}$, $\sigma={sigma}$', color='blue')
# /tmp/ipython-input-1207476062.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y, label=f'Normal Distribution\n$\mu={mu}$, $\sigma={sigma}$', color='blue')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal

# Parameters for the bivariate normal distribution
mu = [0, 0]  # Mean vector (mu_x, mu_y)
sigma = [[1, 0.5],  # Covariance matrix (sigma_xx, sigma_xy)
         [0.5, 1]]  # (sigma_yx, sigma_yy)

# Create a grid of (x, y) values
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Stack the X and Y values into a (n, 2) array
pos = np.dstack((X, Y))

# Create the bivariate normal distribution
rv = multivariate_normal(mu, sigma)

# Calculate the PDF values for each point in the (x, y) grid
Z = rv.pdf(np.dstack((X, Y)))

# Plotting the 3D surface of the bivariate normal distribution
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Density')
ax.set_title('3D Bivariate Normal Distribution')

# Add color bar
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 2D Normal Distribution Visualization
def plot_2d_normal(mu_x=0, mu_y=0, sigma_x=1, sigma_y=1, rho=0, num_points=100):
    # Create grid of (x, y) values
    x = np.linspace(mu_x - 4*sigma_x, mu_x + 4*sigma_x, num_points)
    y = np.linspace(mu_y - 4*sigma_y, mu_y + 4*sigma_y, num_points)
    X, Y = np.meshgrid(x, y)

    # Compute the bivariate normal distribution (PDF)
    Z = np.exp(-0.5 * ((X - mu_x)**2 / sigma_x**2 + (Y - mu_y)**2 / sigma_y**2)) / (2 * np.pi * sigma_x * sigma_y)

    # Plot the 2D normal distribution using contour plot
    plt.figure(figsize=(8, 6))
    cp = plt.contour(X, Y, Z, levels=10, cmap='Blues')
    # plt.title(f"2D Normal Distribution\n$\mu_x={mu_x}$, $\mu_y={mu_y}$, $\sigma_x={sigma_x}$, $\sigma_y={sigma_y}$, $\rho={rho}$")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.colorbar(cp)
    plt.grid(True)
    plt.show()

# Visualize 2D Normal Distribution with mean (0,0) and std dev (1,1)
plot_2d_normal(mu_x=0, mu_y=0, sigma_x=1, sigma_y=1, rho=0)

# %% [markdown]
# <h1 style='text-align: right;'>
# توزیع برنولی
# </h1>

# %%
# @title Section 6: Bernoulli Distribution
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 6: Bernoulli Distribution
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 6: Bernoulli Distribution
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to simulate Bernoulli trials
def simulate_bernoulli(p, n):
    # p is the probability of success, n is the number of trials
    return np.random.binomial(1, p, n)

# Parameters
p = 0.7  # Probability of success (can be adjusted)
n = 1000  # Number of trials

# Simulate the Bernoulli distribution
bernoulli_trials = simulate_bernoulli(p, n)


# Plotting the probability distribution (Bar plot)
plt.figure(figsize=(8, 6))
plt.bar([0, 1], [np.mean(bernoulli_trials == 0), np.mean(bernoulli_trials == 1)], color=['red', 'green'])
plt.title(f'Bernoulli Probability Distribution (p={p})')
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.xticks([0, 1], ['Failure (0)', 'Success (1)'])
plt.grid(True)
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# توزیع دوجمله‌ای
# </h1>

# %%
# @title Section 7: Bionomial Distribution
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 7: Bionomial Distribution
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 7: Bionomial Distribution
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 100  # Number of simulations

# Simulate binomial distribution
binomial_data = np.random.binomial(n, p, size)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(binomial_data, bins=np.arange(-0.5, n+1.5, 1), density=True, alpha=0.6, color='b')

# Labeling the plot
plt.title(f"Binomial Distribution (n={n}, p={p})")
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# توزیع پواسون
# </h1>

# %%
# @title Section 8: Poisson Distribution
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 8: Poisson Distribution
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 8: Poisson Distribution
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_ = 5  # Rate (mean number of occurrences)
size = 1000  # Number of simulations

# Simulate Poisson distribution
poisson_data = np.random.poisson(lambda_, size)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(poisson_data, bins=np.arange(-0.5, max(poisson_data)+1.5, 1), density=True, alpha=0.6, color='g')

# Labeling the plot
plt.title(f"Poisson Distribution (lambda={lambda_})")
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(range(max(poisson_data)+1))
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# <h1 style='text-align: right;'>
# توزیع نمایی
# </h1>

# %%
# @title Section 9: Exponential Distribution
from IPython.display import HTML

HTML('''
<div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
  📘 Section 9: Exponential Distribution
</div>
''')
# Out:
# <div style="padding: 12px; background: linear-gradient(to right, #c471ed, #f7797d); color: white; font-size: 22px; border-radius: 8px; margin-top: 20px;">
#   📘 Section 9: Exponential Distribution
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the exponential distribution
lambda_ = .5  # Rate parameter (1 / mean)
size = 1000  # Number of simulations

# Simulate exponential distribution
exponential_data = np.random.exponential(1/lambda_, size)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(exponential_data, bins=30, density=True, alpha=0.6, color='c')

# Add a line for the probability density function (PDF)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = lambda_ * np.exp(-lambda_ * x)
plt.plot(x, pdf, 'r-', lw=2)

# Labeling the plot
plt.title(f"Exponential Distribution (lambda={lambda_})")
plt.xlabel('Value')
plt.ylabel('Density')
plt.xlim(0, 20)
plt.grid(True)

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# Parameters for the 2D normal distribution
mu_X = 0  # Mean of X
mu_Y = 0  # Mean of Y
sigma_X = 1  # Standard deviation of X
sigma_Y = 1  # Standard deviation of Y
rho = 0.8  # Correlation between X and Y

# Covariance matrix for the joint distribution
cov_matrix = [[sigma_X**2, rho*sigma_X*sigma_Y],
              [rho*sigma_X*sigma_Y, sigma_Y**2]]

# Create a meshgrid for the values of X and Y
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
pos = np.dstack((X, Y))

# Simulate the joint distribution f(x, y)
rv = multivariate_normal([mu_X, mu_Y], cov_matrix)
f_xy = rv.pdf(pos)

# Plot the joint density f(x, y)
plt.figure(figsize=(14, 6))

# First plot: Joint density f(x, y)
plt.subplot(1, 2, 1)
plt.contourf(X, Y, f_xy, cmap='viridis')
plt.colorbar(label='Density')
plt.title('Joint Density f(x, y)')
plt.xlabel('X')
plt.ylabel('Y')

# Conditional density f(y|x) for a fixed value of X (e.g., X = 1)
x_fixed = 1
mean_cond = mu_Y + rho * (sigma_Y / sigma_X) * (x_fixed - mu_X)
var_cond = sigma_Y**2 * (1 - rho**2)
f_y_given_x = (1 / np.sqrt(2 * np.pi * var_cond)) * np.exp(- (y - mean_cond)**2 / (2 * var_cond))

# Second plot: Conditional density f(y|x) for fixed X = 1
plt.subplot(1, 2, 2)
plt.plot(y, f_y_given_x, label=f'Conditional density f(y|x) for X = {x_fixed}', color='orange')
plt.title(f'Conditional Density f(y|x) for X = {x_fixed}')
plt.xlabel('Y')
plt.ylabel('Density')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# پارامترها
p = 0.05  # احتمال معیوب بودن یک قطعه (5%)
n = 100   # تعداد قطعات در هر دسته تولید
k = np.arange(0, n+1)  # تعداد قطعات معیوب در دسته‌ها (از 0 تا n)

# محاسبه توزیع باینومیال برای تعداد معیوب‌ها
pmf = binom.pmf(k, n, p)

# نمایش گراف توزیع احتمال باینومیال
plt.figure(figsize=(10,6))
plt.vlines(k, 0, pmf, colors='b', lw=5)
plt.plot(k, pmf, 'bo', ms=8)
plt.title(f'Tozi\'e Binaomi\'al baraye {n} ghesmat', fontsize=16)
plt.xlabel('Shomare ghesmat mo\'ayeb', fontsize=12)
plt.ylabel('Ihtemal', fontsize=12)
plt.grid(True)
plt.show()

# محاسبه احتمال رد کردن دسته‌ای از قطعات اگر تعداد قطعات معیوب بیش از حد معین باشد
threshold = 10  # تعداد معیوب مجاز
probability_of_rejecting = 1 - binom.cdf(threshold, n, p)
print(f"Emkan reftan daste agar {threshold} ghesmat mo'ayeb bish az in bashad: {probability_of_rejecting:.4f}")
# Out:
# Emkan reftan daste agar 10 ghesmat mo'ayeb bish az in bashad: 0.0115

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# تولید داده‌های مصنوعی برای این مثال
np.random.seed(42)

# تعداد قطعات
n_samples = 1000

# ویژگی‌های تولید (مثلاً دما، فشار، سرعت تولید)
temperature = np.random.normal(loc=25, scale=5, size=n_samples)  # دما (درجه سانتی‌گراد)
pressure = np.random.normal(loc=30, scale=3, size=n_samples)  # فشار (بار)
speed = np.random.normal(loc=100, scale=10, size=n_samples)  # سرعت تولید (دور در دقیقه)

# متغیر هدف (0 سالم، 1 معیوب)
# فرض می‌کنیم که دما، فشار و سرعت تولید تأثیر مستقیم بر معیوب بودن قطعه دارند
def is_defective(temp, pres, speed):
    return (temp > 28) & (pres < 25) | (speed > 110)

defective = is_defective(temperature, pressure, speed)

# ساخت DataFrame
data = pd.DataFrame({
    'temperature': temperature,
    'pressure': pressure,
    'speed': speed,
    'defective': defective
})

# تقسیم داده‌ها به ویژگی‌ها و متغیر هدف
X = data[['temperature', 'pressure', 'speed']]  # ویژگی‌ها
y = data['defective']  # هدف

# تقسیم داده‌ها به داده‌های آموزشی و آزمایشی
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# استانداردسازی داده‌ها
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# مدل درخت تصمیم
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# پیش‌بینی روی داده‌های آزمایشی
y_pred = model.predict(X_test)

# ارزیابی مدل
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# نمایش نتایج
print(f"Accuracy: {accuracy:.4f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)

# نمایش گراف درخت تصمیم
from sklearn.tree import plot_tree
plt.figure(figsize=(12,8))
plot_tree(model, filled=True, feature_names=['temperature', 'pressure', 'speed'], class_names=['Not Defective', 'Defective'], rounded=True)
plt.show()
# Out:
# Accuracy: 0.9967
#
# Confusion Matrix:
# [[257   0]
#  [  1  42]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       257
#         True       1.00      0.98      0.99        43
#
#     accuracy                           1.00       300
#    macro avg       1.00      0.99      0.99       300
# weighted avg       1.00      1.00      1.00       300

# %%
# وارد کردن کتابخانه‌ها
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# بارگذاری دیتاست Iris
iris = load_iris()
X = iris.data  # ویژگی‌ها (طول و عرض گلبرگ و ساقه)
y = iris.target  # برچسب‌ها (نوع گل)

# تقسیم داده‌ها به داده‌های آموزشی و آزمایشی
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# استانداردسازی داده‌ها
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# مدل رگرسیون لجستیک
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

# پیش‌بینی بر روی داده‌های آزمایشی
y_pred = model.predict(X_test)

# ارزیابی مدل
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# نمایش نتایج
print(f"Accuracy: {accuracy:.4f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)

# نمایش گراف ماتریس اشتباه
plt.figure(figsize=(6,6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
classes = iris.target_names
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.tight_layout()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 1.0000
#
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# @title 🎓End of Notebook – Thank You!
from IPython.display import HTML

HTML('''
<div style="margin-top: 40px; padding: 16px; background: linear-gradient(90deg, #ff66b2, #a64ac9); color: white; text-align: center; border-radius: 10px; font-size: 18px;">
  🎓 <strong>End of Notebook – Thank You!</strong>
</div>
''')
# Out:
# <div style="margin-top: 40px; padding: 16px; background: linear-gradient(90deg, #ff66b2, #a64ac9); color: white; text-align: center; border-radius: 10px; font-size: 18px;">
#   🎓 <strong>End of Notebook – Thank You!</strong>
# </div>
